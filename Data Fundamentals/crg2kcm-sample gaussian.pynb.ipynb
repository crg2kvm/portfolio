# %%
import numpy as np
import random
import matplotlib as plt
import pandas as pd

# %%
I = [[1,0],[0,1]]
D = [[7,0],[0,11]]
mean = [0,0]
#mean = np.array(mean)
n = 500

id_dat = []
d_dat = []

id_dat = np.random.multivariate_normal(mean,I,500)
d_dat = np.random.multivariate_normal(mean,D,500)

#print(id_dat)

# %%
id_df = pd.DataFrame(id_dat,columns=['x','y'])
d_df = pd.DataFrame(d_dat, columns=['x','y'])

id_df.plot.scatter('x','y')
d_df.plot.scatter('x','y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>
